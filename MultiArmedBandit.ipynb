# %%
include("runexp.jl");

# %% [markdown]
# # Test

# %%
D = RareDist(0.1, -10., Normal(10, 4))

N = 100000

X = zeros(N)

for i = 1:N
    x = rand(D)
    X[i] = x
end

plt[:hist](X)

;
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31d4302d0>)

# %%
runExp([Bernoulli(0.9), Bernoulli(0.6)], 1, Any[:UCB1], bPlot = true);
#runExp([Bernoulli(0.9), Bernoulli(0.8)], 1, Any[:UCB1], bPlot = true);
#runExp([Bernoulli(0.55), Bernoulli(0.45)], 1, Any[:UCB1], bPlot = true);
#runExp([Normal(3, 2), Normal(5, 8), Normal(2, 11)], 2, Any[:UCB1], bPlot = true);

#runExpN(100, [Bernoulli(0.9), Bernoulli(0.6)], 1, Any[:UCB1], bPlot = true);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31a696e90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31db39350>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31ef6f110>)

# %% [markdown]
# # Bernoulli

# %%
plotExpPolicy([Bernoulli(0.9), Bernoulli(0.6)], 1, Any[Any[:UCB1], Any[:UCB1_tuned], Any[:UCB_V]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x30d89cad0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31d5ce290>)

# %%
plotExpPolicy([Bernoulli(0.9), Bernoulli(0.8)], 1, Any[Any[:UCB1], Any[:UCB1_tuned], Any[:UCB_V]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31a6bad10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x324f49590>)

# %%
plotExpPolicy([Bernoulli(0.55), Bernoulli(0.45)], 1, Any[Any[:UCB1], Any[:UCB1_tuned], Any[:UCB_V]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x324f09910>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31d5bc490>)

# %% [markdown]
# # Normal

# %%
plotExpParam([Normal(3, 2), Normal(5, 8), Normal(2, 11)], 2, :UCB1, [1, 10, 100], N = 30)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f09bb50>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x320429590>)

# %%
plotExpParam([Normal(3, 2), Normal(5, 8), Normal(2, 11)], 2, :UCB1_tuned, [1, 10, 100, 1000], N = 30)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x318c57b10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3148b8d50>)

# %%
plotExpParam([Normal(3, 2), Normal(5, 8), Normal(2, 11)], 2, :UCB_V, [0, 1, 10], N = 30)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x320432b90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f115c50>)

# %%
plotExpPolicy([Normal(3, 2), Normal(5, 8), Normal(2, 11)], 2, Any[Any[:UCB1, 10], Any[:UCB1_tuned, 100], Any[:UCB_V]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b7d5e90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31c03e450>)

# %% [markdown]
# # RareDist

# %% [markdown]
# ## Set 1

# %%
plotExpParam([RareDist(0.1, -1000., Normal(10, 4)), Normal(10, 4)], 2, :UCB1, [1, 10, 100], N = 30)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f0c2350>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f128d50>)

# %%
plotExpParam([RareDist(0.1, -1000., Normal(10, 4)), Normal(10, 4)], 2, :UCB1_tuned, [1, 10, 20, 30], N = 30)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x318a4ff50>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3194a50d0>)

# %%
plotExpParam([RareDist(0.1, -1000., Normal(10, 4)), Normal(10, 4)], 2, :UCB_V, [0, 1, 10], N = 30)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32063ac50>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31fa19c90>)

# %%
plotExpPolicy([RareDist(0.1, -1000., Normal(10, 4)), Normal(10, 4)], 2, Any[Any[:UCB1], Any[:UCB1_tuned], Any[:UCB_V, 0]], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31c029b90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32064b5d0>)

# %% [markdown]
# ## Set 2

# %%
plotExpPolicy([RareDist(0.01, -1000., Normal(10, 4)), Normal(10, 4)], 2, Any[Any[:UCB1], Any[:UCB1_tuned], Any[:UCB_V, 0]], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f55a4d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f109590>)

# %%
plotExpPolicy([RareDist(0.5, -1000., Normal(10, 4)), Normal(10, 4)], 2, Any[Any[:UCB1], Any[:UCB1_tuned], Any[:UCB_V, 0]], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b7eff10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x320659450>)

# %%
plotExpParam([RareDist(0.01, -1000., Normal(30, 4)), Normal(10, 4)], 1, :UCB1_tuned, [1, 10, 100, 1000, 10000], N = 30)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f3323d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f0a6250>)

# %%
runExp([RareDist(0.01, -1000., Normal(30, 4)), Normal(10, 4)], 1, Any[:UCB1_tuned, 10000], bPlot = true);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31ef6d390>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f11d9d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32061a790>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x322b702d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31efe85d0>)

# %%
plotExpPolicy([RareDist(0.01, -1000., Normal(30, 4)), Normal(10, 4)], 1, Any[Any[:UCB1], Any[:UCB1_tuned], Any[:UCB_V]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f2f0b90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f51be10>)

# %%
runExp([RareDist(0.1, -1000., Normal(30, 4)), Normal(10, 4)], 2, Any[:UCB_V], bPlot = true);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x324da78d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3239383d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x324d73e50>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f5349d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x322e56e10>)

# %%
plotExpPolicy([RareDist(0.1, -1000., Normal(30, 4)), Normal(10, 4)], 2, Any[Any[:UCB1], Any[:UCB1_tuned], Any[:UCB_V]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b7db690>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f337590>)

# %% [markdown]
# ## Set 3a

# %%
plotExpParam([Truncated(Normal(-30, 4), -Inf, 0), Truncated(Normal(-70, 4), -Inf, 0)], 1, :UCB1, [1, 10, 100], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b7d1350>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x30ea1f6d0>)

# %%
plotExpParam([Truncated(Normal(-30, 4), -Inf, 0), Truncated(Normal(-70, 4), -Inf, 0)], 1, :UCB_VAR, [(10, 0), (10, 1), (10, 10)], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e676d10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b2bc290>)

# %%
plotExpPolicy([Truncated(Normal(-30, 4), -Inf, 0), Truncated(Normal(-70, 4), -Inf, 0)], 1, Any[Any[:UCB1, 10], Any[:UCB_VAR, (10, 1)]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3202463d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31bac1d90>)

# %% [markdown]
# ## Set 3b

# %%
plotExpParam([RareDist(0.01, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-70, 4), -Inf, 0)], 1, :UCB1, [1, 10, 100, 1000], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e958850>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b8f4c50>)

# %%
plotExpParam([RareDist(0.01, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-70, 4), -Inf, 0)], 1, :UCB_VAR, [(100, 0), (100, 1), (100, 10), (100, 100)], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31ba6a990>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f551fd0>)

# %%
plotExpPolicy([RareDist(0.01, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-70, 4), -Inf, 0)], 1, Any[Any[:UCB1, 100], Any[:UCB_VAR, (100, 1)]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31ff2cc90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e6a3ed0>)

# %% [markdown]
# ## Set 3c

# %%
plotExpParam([RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-70, 4), -Inf, 0)], 2, :UCB1, [1, 10, 100, 200], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31dae8790>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31db4a450>)

# %%
plotExpParam([RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-70, 4), -Inf, 0)], 2, :UCB_VAR, [(100, 0), (100, 1), (100, 10), (100, 100)], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b8f2850>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31dcf9c10>)

# %%
plotExpPolicy([RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-70, 4), -Inf, 0)], 2, Any[Any[:UCB1, 100], Any[:UCB_VAR, (100, 1)]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31fa08810>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x30e9de750>)

# %% [markdown]
# ## Set 3d

# %%
plotExpParam([RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-30, 4), -Inf, 0)], 2, :UCB1, [1, 10, 100, 200], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b273890>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31ba59590>)

# %%
plotExpParam([RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-30, 4), -Inf, 0)], 2, :UCB_VAR, [(1, 0), (1, 1), (1, 10), (1, 100)], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f9dea10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31fa1a590>)

# %%
plotExpPolicy([RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-30, 4), -Inf, 0)], 2, Any[Any[:UCB1, 1], Any[:UCB_VAR, (1, 1)]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b2bf850>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x30ea0dc10>)

# %% [markdown]
# ## Set 3e

# %%
plotExpParam([RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-10, 4), -Inf, 0)], 2, :UCB1, [1, 10, 100, 200], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b2a3a10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31bad2c50>)

# %%
plotExpParam([RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-10, 4), -Inf, 0)], 2, :UCB_VAR, [(1, 0), (1, 1), (1, 10), (1, 100)], N = 30);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31f9cb890>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31e699c10>)

# %%
plotExpPolicy([RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0)), Truncated(Normal(-10, 4), -Inf, 0)], 2, Any[Any[:UCB1, 1], Any[:UCB_VAR, (1, 1)]]);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31fa6fb50>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31ba80550>)

# %% [markdown]
# ## Set 3 Test

# %%
D = RareDist(0.1, -1000., Truncated(Normal(-30, 4), -Inf, 0))

N = 100000

X = zeros(N)

for i = 1:N
    x = rand(D)
    X[i] = x
end

println(std(X))

;
# Out:
# 292.37147444604113
